# %% [markdown]
# # Intro to ML HW

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.2'

# %%
df =pd.read_csv("./data/housing.csv")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.total_bedrooms.isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: total_bedrooms, Length: 20640, dtype: bool

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
len(df.ocean_proximity.unique())
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df2 = df[df.ocean_proximity == 'NEAR BAY']

# %%
df2.median_house_value.mean()
# Out:
# 259212.31179039303

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.total_bedrooms.mean()
# Out:
# 537.8705525375618

# %%
df.total_bedrooms.fillna(df2.median_house_value.mean())
# Out:
# 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
#           ...
# 20635     374.0
# 20636     150.0
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20640, dtype: float64

# %%
df.total_bedrooms.mean()
# Out:
# 537.8705525375618

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df_ocean=df[df.ocean_proximity == "INLAND"]

# %%
df_ocean
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_new = df_ocean[["housing_median_age", "total_rooms","total_bedrooms"]]

# %%
df_new
# Out:
#        housing_median_age  total_rooms  total_bedrooms
# 0                    41.0        880.0           129.0
# 1                    21.0       7099.0          1106.0
# 2                    52.0       1467.0           190.0
# 3                    52.0       1274.0           235.0
# 4                    52.0       1627.0           280.0
# ...                   ...          ...             ...
# 20635                25.0       1665.0           374.0
# 20636                18.0        697.0           150.0
# 20637                17.0       2254.0           485.0
# 20638                18.0       1860.0           409.0
# 20639                16.0       2785.0           616.0
#
# [20640 rows x 3 columns]

# %%
import numpy as np
y = np.array([950, 1300, 800, 1000, 1300])

# %%
x= df_new.to_numpy()

# %%
xtx = x * x.T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 xtx = x * x.T
#
# ValueError: operands could not be broadcast together with shapes (20640,3) (3,20640)

# %%
xtx * y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 xtx * y
#
# ValueError: operands could not be broadcast together with shapes (3,20640) (5,)
